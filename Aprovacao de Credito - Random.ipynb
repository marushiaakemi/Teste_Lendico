# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score, roc_curve, classification_report,accuracy_score, confusion_matrix, auc
from sklearn.ensemble import RandomForestClassifier

# %%
train = pd.read_csv('case_train.csv')
test = pd.read_csv('case_test.csv')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77000 entries, 0 to 76999
# Data columns (total 15 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   inadimplente                           77000 non-null  int64
#  1   util_linhas_inseguras                  53181 non-null  float64
#  2   idade                                  46770 non-null  float64
#  3   vezes_passou_de_30_59_dias             77000 non-null  int64
#  4   razao_debito                           77000 non-null  float64
#  5   salario_mensal                         25662 non-null  float64
#  6   numero_linhas_crdto_aberto             77000 non-null  int64
#  7   numero_vezes_passou_90_dias            39498 non-null  float64
#  8   numero_emprestimos_imobiliarios        77000 non-null  int64
#  9   numero_de_vezes_que_passou_60_89_dias  17131 non-null  float64
#  10  numero_de_dependentes                  64854 non-null  float64
#  11  score_1                                77000 non-null  object
#  12  score_2                                77000 non-null  int64
#  13  score_3                                77000 non-null  object
#  14  score_4                                30131 non-null  float64
# dtypes: float64(8), int64(5), object(2)
# memory usage: 8.2+ MB

# %%
train.describe()
# Out:
#        inadimplente  util_linhas_inseguras         idade  \
# count  77000.000000           53181.000000  46770.000000
# mean       0.066442               6.772273     52.265427
# std        0.249054             315.201012     14.787977
# min        0.000000               0.000000      0.000000
# 25%        0.000000               0.029332     41.000000
# 50%        0.000000               0.152994     52.000000
# 75%        0.000000               0.564008     63.000000
# max        1.000000           50708.000000    109.000000
#
#        vezes_passou_de_30_59_dias   razao_debito  salario_mensal  \
# count                77000.000000   77000.000000    25662.000000
# mean                     0.418857     359.625289     6624.034097
# std                      4.218858    2331.349453     8153.270844
# min                      0.000000       0.000000        0.000000
# 25%                      0.000000       0.175372     3400.000000
# 50%                      0.000000       0.367070     5400.000000
# 75%                      0.000000       0.869616     8268.000000
# max                     98.000000  329664.000000   699530.000000
#
#        numero_linhas_crdto_aberto  numero_vezes_passou_90_dias  \
# count                77000.000000                 39498.000000
# mean                     8.438909                     0.247177
# std                      5.141286                     3.966419
# min                      0.000000                     0.000000
# 25%                      5.000000                     0.000000
# 50%                      8.000000                     0.000000
# 75%                     11.000000                     0.000000
# max                     57.000000                    98.000000
#
#        numero_emprestimos_imobiliarios  numero_de_vezes_que_passou_60_89_dias  \
# count                     77000.000000                           17131.000000
# mean                          1.019779                               0.274707
# std                           1.110459                               4.555894
# min                           0.000000                               0.000000
# 25%                           0.000000                               0.000000
# 50%                           1.000000                               0.000000
# 75%                           2.000000                               0.000000
# max                          25.000000                              98.000000
#
#        numero_de_dependentes       score_2       score_4
# count           64854.000000  77000.000000  30131.000000
# mean                0.757548    406.900312    500.935515
# std                 1.118085    232.479887    288.359625
# min                 0.000000      0.000000      0.000000
# 25%                 0.000000    208.000000    252.000000
# 50%                 0.000000    408.000000    501.000000
# 75%                 1.000000    606.000000    751.000000
# max                20.000000    998.000000   1000.000000

# %%
train.head(10)
# Out:
#    inadimplente  util_linhas_inseguras  idade  vezes_passou_de_30_59_dias  \
# 0             0                    NaN    NaN                           0
# 1             0                    NaN   47.0                           0
# 2             0               1.078921   26.0                           0
# 3             0               0.553878    NaN                           0
# 4             0               0.034962   35.0                           1
# 5             0               0.000000   72.0                           0
# 6             0               0.871408    NaN                           0
# 7             1               0.948112   39.0                           0
# 8             0                    NaN   42.0                           1
# 9             0               1.000000   28.0                           0
#
#    razao_debito  salario_mensal  numero_linhas_crdto_aberto  \
# 0      0.102518             NaN                           3
# 1      0.162967             NaN                          10
# 2      0.017768          1800.0                           1
# 3      1.193871          1500.0                           8
# 4   3266.000000             NaN                           5
# 5    262.000000             NaN                           1
# 6   1943.000000             NaN                           9
# 7      0.823588             NaN                           7
# 8   1658.000000             NaN                           4
# 9      0.008283             NaN                           0
#
#    numero_vezes_passou_90_dias  numero_emprestimos_imobiliarios  \
# 0                          0.0                                0
# 1                          0.0                                1
# 2                          0.0                                0
# 3                          NaN                                0
# 4                          0.0                                1
# 5                          NaN                                0
# 6                          0.0                                1
# 7                          0.0                                0
# 8                          NaN                                1
# 9                          0.0                                0
#
#    numero_de_vezes_que_passou_60_89_dias  numero_de_dependentes score_1  \
# 0                                    NaN                    NaN       f
# 1                                    NaN                    0.0       h
# 2                                    NaN                    0.0       q
# 3                                    NaN                    NaN       h
# 4                                    NaN                    NaN       o
# 5                                    NaN                    1.0       v
# 6                                    NaN                    0.0       h
# 7                                    NaN                    0.0       o
# 8                                    NaN                    NaN       i
# 9                                    NaN                    0.0       h
#
#    score_2 score_3  score_4
# 0      278       g    708.0
# 1      428       g      NaN
# 2      268       b    273.0
# 3      566       f      NaN
# 4       81       d    255.0
# 5      641       g    181.0
# 6      517       d      NaN
# 7      729       c      NaN
# 8       77       g     92.0
# 9      422       d      NaN

# %%
aux = pd.DataFrame({
    'colunas': train.columns,
    'tipos': train.dtypes,
    'percentual_faltante': train.isna().sum() / train.shape[0]
}
)
aux
# Out:
#                                                                      colunas  \
# inadimplente                                                    inadimplente
# util_linhas_inseguras                                  util_linhas_inseguras
# idade                                                                  idade
# vezes_passou_de_30_59_dias                        vezes_passou_de_30_59_dias
# razao_debito                                                    razao_debito
# salario_mensal                                                salario_mensal
# numero_linhas_crdto_aberto                        numero_linhas_crdto_aberto
# numero_vezes_passou_90_dias                      numero_vezes_passou_90_dias
# numero_emprestimos_imobiliarios              numero_emprestimos_imobiliarios
# numero_de_vezes_que_passou_60_89_dias  numero_de_vezes_que_passou_60_89_dias
# numero_de_dependentes                                  numero_de_dependentes
# score_1                                                              score_1
# score_2                                                              score_2
# score_3                                                              score_3
# score_4                                                              score_4
#
#                                          tipos  percentual_faltante
# inadimplente                             int64             0.000000
# util_linhas_inseguras                  float64             0.309338
# idade                                  float64             0.392597
# vezes_passou_de_30_59_dias               int64             0.000000
# razao_debito                           float64             0.000000
# salario_mensal                         float64             0.666727
# numero_linhas_crdto_aberto               int64             0.000000
# numero_vezes_passou_90_dias            float64             0.487039
# numero_emprestimos_imobiliarios          int64             0.000000
# numero_de_vezes_que_passou_60_89_dias  float64             0.777519
# numero_de_dependentes                  float64             0.157740
# score_1                                 object             0.000000
# score_2                                  int64             0.000000
# score_3                                 object             0.000000
# score_4                                float64             0.608688

# %%
train['numero_vezes_passou_90_dias'].fillna(0, inplace = True)
train['numero_de_vezes_que_passou_60_89_dias'].fillna(0, inplace = True)
train['numero_de_dependentes'].fillna(0, inplace = True)
train['salario_mensal'].fillna(train.salario_mensal.mode()[0], inplace = True)
train['idade'].fillna(train.idade.mode()[0], inplace=True)
train['util_linhas_inseguras'].fillna(train.util_linhas_inseguras.median(), inplace = True)
train['score_4'].fillna(train['score_2'], inplace = True)


test['numero_vezes_passou_90_dias'].fillna(0, inplace = True)
test['numero_de_vezes_que_passou_60_89_dias'].fillna(0, inplace = True)
test['numero_de_dependentes'].fillna(0, inplace = True)
test['salario_mensal'].fillna(test.salario_mensal.mode()[0], inplace = True)
test['idade'].fillna(test.idade.mode()[0], inplace=True)
test['util_linhas_inseguras'].fillna(test.util_linhas_inseguras.median(), inplace = True)
test['score_4'].fillna(test['score_2'], inplace = True)

# %%
train.corr()
# Out:
#                                        inadimplente  util_linhas_inseguras  \
# inadimplente                               1.000000              -0.002188
# util_linhas_inseguras                     -0.002188               1.000000
# idade                                     -0.085357              -0.002950
# vezes_passou_de_30_59_dias                 0.123579              -0.000928
# razao_debito                              -0.005876               0.000355
# salario_mensal                            -0.018312               0.001614
# numero_linhas_crdto_aberto                -0.033262              -0.005384
# numero_vezes_passou_90_dias                0.080917              -0.000680
# numero_emprestimos_imobiliarios           -0.012406               0.010572
# numero_de_vezes_que_passou_60_89_dias      0.054822              -0.000438
# numero_de_dependentes                      0.040030              -0.002795
# score_2                                    0.105761              -0.003885
# score_4                                    0.056658              -0.005876
#
#                                           idade  vezes_passou_de_30_59_dias  \
# inadimplente                          -0.085357                    0.123579
# util_linhas_inseguras                 -0.002950                   -0.000928
# idade                                  1.000000                   -0.050758
# vezes_passou_de_30_59_dias            -0.050758                    1.000000
# razao_debito                           0.012299                   -0.006347
# salario_mensal                         0.013713                   -0.010527
# numero_linhas_crdto_aberto             0.108687                   -0.056352
# numero_vezes_passou_90_dias           -0.037801                    0.664793
# numero_emprestimos_imobiliarios        0.023322                   -0.032032
# numero_de_vezes_que_passou_60_89_dias -0.021201                    0.507020
# numero_de_dependentes                 -0.148295                   -0.002209
# score_2                               -0.006184                    0.022627
# score_4                               -0.002058                    0.013790
#
#                                        razao_debito  salario_mensal  \
# inadimplente                              -0.005876       -0.018312
# util_linhas_inseguras                      0.000355        0.001614
# idade                                      0.012299        0.013713
# vezes_passou_de_30_59_dias                -0.006347       -0.010527
# razao_debito                               1.000000       -0.022000
# salario_mensal                            -0.022000        1.000000
# numero_linhas_crdto_aberto                 0.040727        0.096146
# numero_vezes_passou_90_dias               -0.005244       -0.006688
# numero_emprestimos_imobiliarios            0.112872        0.118011
# numero_de_vezes_que_passou_60_89_dias     -0.003417       -0.007295
# numero_de_dependentes                     -0.036920        0.065559
# score_2                                    0.000036       -0.005973
# score_4                                   -0.003655       -0.003416
#
#                                        numero_linhas_crdto_aberto  \
# inadimplente                                            -0.033262
# util_linhas_inseguras                                   -0.005384
# idade                                                    0.108687
# vezes_passou_de_30_59_dias                              -0.056352
# razao_debito                                             0.040727
# salario_mensal                                           0.096146
# numero_linhas_crdto_aberto                               1.000000
# numero_vezes_passou_90_dias                             -0.055149
# numero_emprestimos_imobiliarios                          0.435330
# numero_de_vezes_que_passou_60_89_dias                   -0.036500
# numero_de_dependentes                                    0.066871
# score_2                                                 -0.006096
# score_4                                                 -0.003238
#
#                                        numero_vezes_passou_90_dias  \
# inadimplente                                              0.080917
# util_linhas_inseguras                                    -0.000680
# idade                                                    -0.037801
# vezes_passou_de_30_59_dias                                0.664793
# razao_debito                                             -0.005244
# salario_mensal                                           -0.006688
# numero_linhas_crdto_aberto                               -0.055149
# numero_vezes_passou_90_dias                               1.000000
# numero_emprestimos_imobiliarios                          -0.031955
# numero_de_vezes_que_passou_60_89_dias                     0.305381
# numero_de_dependentes                                    -0.004914
# score_2                                                   0.012832
# score_4                                                   0.009110
#
#                                        numero_emprestimos_imobiliarios  \
# inadimplente                                                 -0.012406
# util_linhas_inseguras                                         0.010572
# idade                                                         0.023322
# vezes_passou_de_30_59_dias                                   -0.032032
# razao_debito                                                  0.112872
# salario_mensal                                                0.118011
# numero_linhas_crdto_aberto                                    0.435330
# numero_vezes_passou_90_dias                                  -0.031955
# numero_emprestimos_imobiliarios                               1.000000
# numero_de_vezes_que_passou_60_89_dias                        -0.021082
# numero_de_dependentes                                         0.115765
# score_2                                                      -0.002918
# score_4                                                      -0.001017
#
#                                        numero_de_vezes_que_passou_60_89_dias  \
# inadimplente                                                        0.054822
# util_linhas_inseguras                                              -0.000438
# idade                                                              -0.021201
# vezes_passou_de_30_59_dias                                          0.507020
# razao_debito                                                       -0.003417
# salario_mensal                                                     -0.007295
# numero_linhas_crdto_aberto                                         -0.036500
# numero_vezes_passou_90_dias                                         0.305381
# numero_emprestimos_imobiliarios                                    -0.021082
# numero_de_vezes_que_passou_60_89_dias                               1.000000
# numero_de_dependentes                                              -0.002804
# score_2                                                             0.011667
# score_4                                                             0.013364
#
#                                        numero_de_dependentes   score_2  \
# inadimplente                                        0.040030  0.105761
# util_linhas_inseguras                              -0.002795 -0.003885
# idade                                              -0.148295 -0.006184
# vezes_passou_de_30_59_dias                         -0.002209  0.022627
# razao_debito                                       -0.036920  0.000036
# salario_mensal                                      0.065559 -0.005973
# numero_linhas_crdto_aberto                          0.066871 -0.006096
# numero_vezes_passou_90_dias                        -0.004914  0.012832
# numero_emprestimos_imobiliarios                     0.115765 -0.002918
# numero_de_vezes_que_passou_60_89_dias              -0.002804  0.011667
# numero_de_dependentes                               1.000000 -0.001228
# score_2                                            -0.001228  1.000000
# score_4                                            -0.002875  0.544831
#
#                                         score_4
# inadimplente                           0.056658
# util_linhas_inseguras                 -0.005876
# idade                                 -0.002058
# vezes_passou_de_30_59_dias             0.013790
# razao_debito                          -0.003655
# salario_mensal                        -0.003416
# numero_linhas_crdto_aberto            -0.003238
# numero_vezes_passou_90_dias            0.009110
# numero_emprestimos_imobiliarios       -0.001017
# numero_de_vezes_que_passou_60_89_dias  0.013364
# numero_de_dependentes                 -0.002875
# score_2                                0.544831
# score_4                                1.000000

# %%
y = train['inadimplente']

features1 = ['idade',
       'vezes_passou_de_30_59_dias',  'salario_mensal',
       'numero_linhas_crdto_aberto', 'numero_vezes_passou_90_dias',       
       'numero_de_vezes_que_passou_60_89_dias', 'numero_de_dependentes', 'score_2', 'score_4']

features = [ 
       'vezes_passou_de_30_59_dias',  
      'numero_vezes_passou_90_dias',       
       'numero_de_vezes_que_passou_60_89_dias', 'score_2', 'score_4']

# %%
train[features].corr()
# Out:
#                                        vezes_passou_de_30_59_dias  \
# vezes_passou_de_30_59_dias                               1.000000
# numero_vezes_passou_90_dias                              0.664793
# numero_de_vezes_que_passou_60_89_dias                    0.507020
# score_2                                                  0.022627
# score_4                                                  0.013790
#
#                                        numero_vezes_passou_90_dias  \
# vezes_passou_de_30_59_dias                                0.664793
# numero_vezes_passou_90_dias                               1.000000
# numero_de_vezes_que_passou_60_89_dias                     0.305381
# score_2                                                   0.012832
# score_4                                                   0.009110
#
#                                        numero_de_vezes_que_passou_60_89_dias  \
# vezes_passou_de_30_59_dias                                          0.507020
# numero_vezes_passou_90_dias                                         0.305381
# numero_de_vezes_que_passou_60_89_dias                               1.000000
# score_2                                                             0.011667
# score_4                                                             0.013364
#
#                                         score_2   score_4
# vezes_passou_de_30_59_dias             0.022627  0.013790
# numero_vezes_passou_90_dias            0.012832  0.009110
# numero_de_vezes_que_passou_60_89_dias  0.011667  0.013364
# score_2                                1.000000  0.544831
# score_4                                0.544831  1.000000

# %%
modelo = RandomForestClassifier()
modelo.fit(train[features], y)
y_pred = modelo.predict(test[features])

# %%
modelo.fit(train[features], y)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
confusion_matrix(y, modelo.predict(train[features]))
# Out:
# array([[71820,    64],
#        [ 1883,  3233]], dtype=int64)

# %%
pd.crosstab(y, modelo.predict(train[features]))
# Out:
# col_0             0     1
# inadimplente
# 0             71820    64
# 1              1883  3233

# %%
modelo.score(train[features],y)
# Out:
# 0.9747142857142858

# %%
pred = modelo.predict(test[features])

# %%
test['inadimplente'] = pred.round()

# %%
test.to_csv('teste.csv', index=False, header=True )

# %%
acuracia = accuracy_score(y, modelo.predict(train[features]))

# %%
print(classification_report(y, modelo.predict(train[features])))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99     71884
#            1       0.98      0.63      0.77      5116
#
#     accuracy                           0.97     77000
#    macro avg       0.98      0.82      0.88     77000
# weighted avg       0.97      0.97      0.97     77000

# %%
yhat = modelo.predict_proba(train[features])

# %%
yhat = yhat[:, 1]

# %%
print('AUC: %0.2f' % roc_auc_score(y, yhat))
# Out:
# AUC: 0.94

# %%
def plot_roc_curve(y_true, y_score, figsize=(10,6)):
    fpr, tpr, _ = roc_curve(y_true, y_score)
    plt.figure(figsize=figsize)
    auc_value = roc_auc_score(y_true, y_score)
    plt.plot(fpr, tpr, color='orange', label='ROC curve (area = %0.2f)' % auc_value)
    plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend()
    plt.show()

# %%
plot_roc_curve(y, yhat)
